# %% [markdown]
# # DataFrame Analysis Exercise
#
# **Import the `bestsellers.csv` dataset and use it to answer the following questions:**
#
# * Find the lowest User Rating in the DF - 3.3
# * Find the highest Price in the DF - 105
# * What is the average User Rating? - 4.6
# * What the average User Rating of the first 5 rows? - 4.7
# * What User Review score appeared the most? - 4.8
# * What is the total (sum) of all the values in the Reviews column? - 6574305
# * How many different authors are featured in the dataset? - 248
# * Which author wrote the most number of books on the list?  How many did they write? - Jeff Kiney, 12

# %%
import pandas as pd

# %%
bestsellers = pd.read_csv("data/bestsellers.csv")
bestsellers
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
bestsellers.min()
# Out:
# Name           10-Day Green Smoothie Cleanse
# Author                      Abraham Verghese
# User Rating                              3.3
# Reviews                                   37
# Price                                      0
# Year                                    2009
# Genre                                Fiction
# dtype: object

# %%
bestsellers.max()
# Out:
# Name           You Are a Badass: How to Stop Doubting Your Gr...
# Author                                              Zhi Gang Sha
# User Rating                                                  4.9
# Reviews                                                    87841
# Price                                                        105
# Year                                                        2019
# Genre                                                Non Fiction
# dtype: object

# %%
bestsellers.mean()
# Out:
# /var/folders/_s/sqxf8c615s93slr8fbrlrtth0000gq/T/ipykernel_16778/1813816453.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   bestsellers.mean()
# User Rating        4.618364
# Reviews        11953.281818
# Price             13.100000
# Year            2014.000000
# dtype: float64

# %%
bestsellers.head(5).mean()
# Out:
# /var/folders/_s/sqxf8c615s93slr8fbrlrtth0000gq/T/ipykernel_16778/2420701358.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   bestsellers.head(5).mean()
# User Rating        4.7
# Reviews        13494.0
# Price             12.6
# Year            2016.2
# dtype: float64

# %%
bestsellers.mode()
# Out:
#                                                  Name       Author  \
# 0   Publication Manual of the American Psychologic...  Jeff Kinney
# 1                                                 NaN          NaN
# 2                                                 NaN          NaN
# 3                                                 NaN          NaN
# 4                                                 NaN          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN          NaN
# 7                                                 NaN          NaN
# 8                                                 NaN          NaN
# 9                                                 NaN          NaN
# 10                                                NaN          NaN
#
#     User Rating  Reviews  Price  Year        Genre
# 0           4.8   8580.0    8.0  2009  Non Fiction
# 1           NaN      NaN    NaN  2010          NaN
# ...

# %%
bestsellers.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %%
bestsellers.describe(include = ("O", "float64"))
# Out:
#                                                      Name       Author  \
# count                                                 550          550
# unique                                                351          248
# top     Publication Manual of the American Psychologic...  Jeff Kinney
# freq                                                   10           12
# mean                                                  NaN          NaN
# std                                                   NaN          NaN
# min                                                   NaN          NaN
# 25%                                                   NaN          NaN
# 50%                                                   NaN          NaN
# 75%                                                   NaN          NaN
# max                                                   NaN          NaN
#
#         User Rating        Genre
# count    550.000000          550
# unique          NaN            2
# ...

# %%
bestsellers.sum()
# Out:
# Name           10-Day Green Smoothie Cleanse11/22/63: A Novel...
# Author         JJ SmithStephen KingJordan B. PetersonGeorge O...
# User Rating                                               2540.1
# Reviews                                                  6574305
# Price                                                       7205
# Year                                                     1107700
# Genre          Non FictionFictionNon FictionFictionNon Fictio...
# dtype: object
